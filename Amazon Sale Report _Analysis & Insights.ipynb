# %% [markdown]
# # Amazon Sale Report: Analysis & Insights

# %% [markdown]
# ## 🗂 DATASET LINK

# %% [markdown]
#  https://www.kaggle.com/datasets/thedevastator/unlock-profits-with-e-commerce-sales-data/code

# %% [markdown]
# _________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 📚 ABOUT DATASET

# %% [markdown]
# ### The dataset contains 128,975 rows and 24 columns.

# %% [markdown]
# * Column Data Types :   The columns are a mix of data types, including:
#
# * Numerical :      Index, Qty, Amount, ship-postal-code.
#
# * Categorical/Text :    Order ID, Status, Fulfilment, Category, Size, Style, SKU, and many others.
#
# * Boolean :       B2B.
#
# * Datetime :      The Date column has been standardized to the datetime64[ns] format.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### ♦️ DESCRIPTION OF COLUMNS IN DATASET
#
#
# |Column Name|Description|
# |-----------|-----------|
# |index|An auto-generated row index for the dataset.|
# |Order ID|A unique identifier for each order.|
# |Date|The date the order was placed. This column has been standardized to a datetime format.|
# |Status|The current status of the order (e.g., 'Cancelled', 'Shipped').|
# |Fulfilment|The party responsible for fulfilling the order (e.g., 'Merchant', 'Amazon').|
# |Sales Channel|The channel through which the sale was made (e.g., 'Amazon.in').|
# |ship-service-level|The shipping service level (e.g., 'Standard', 'Expedited').|
# |Style|A style code for the product.|
# |SKU|The Stock Keeping Unit, a unique code for each product.|
# |Category|The product's category (e.g., 'Set', 'kurta', 'Western Dress').|
# |Size|The size of the product (e.g., 'S', '3XL', 'XL').|
# |ASIN|The Amazon Standard Identification Number for the product.|
# |Courier Status|The status of the courier delivery.|
# |QTY|The quantity of the item ordered.|
# |Currency|The currency used for the transaction.|
# |Amount|The total amount of the order.|
# |Ship-City|The city where the order was shipped.|
# |ship-state|The state where the order was shipped.|
# |ship-postal-code|The postal code for the shipping address.|
# |ship-country|The country where the order was shipped.|
# |promotion-ids|A list of promotion IDs applied to the order.|
# |B2B|A boolean indicating if the order was a business-to-business transaction.|
# |fulfilled-by|The party that fulfilled the order.|
# |Unnamed: 22|An un-named column with a high number of missing values. It likely contains no useful data.|

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ## ♦️ Missing Values :
#
# Several columns have a significant number of missing values, which is important to consider for any analysis:
#
# * Courier Status
#
# * Currency
#
# * Amount
#
# * ship-city, ship-state, ship-postal-code, ship-country
#
# * promotion-ids
#
# * fulfilled-by
#
# * Unnamed: 22
#
# This dataset provides a detailed record of Amazon sales, including order specifics, fulfillment details, and shipping information.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 📜 PROJECT OBJECTIVE:

# %% [markdown]
# ### 🔴 Sales Performance Analysis:

# %% [markdown]
# *  To understand sales trends over time, identify top-performing products, and analyze the impact of promotions.

# %% [markdown]
# ### 🔴 Order and Fulfillment Analysis:

# %% [markdown]
# * To assess the efficiency of the order fulfillment process and identify potential issues.

# %% [markdown]
# ### 🔴 Customer and Geographic Analysis:

# %% [markdown]
# * To understand the geographic distribution of sales and identify key customer segments.

# %% [markdown]
# _________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 🌍 IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 📤 READING CSV

# %%
df = pd.read_csv(r'C:\Users\Surface Pro\Desktop\ENTRI APP\phython\self_projects\AMAZON\Amazon Sale Report.csv')
df
# Out:
# C:\Users\Surface Pro\AppData\Local\Temp\ipykernel_17728\4820861.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\Surface Pro\Desktop\ENTRI APP\phython\self_projects\AMAZON\Amazon Sale Report.csv')
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# ...

# %% [markdown]
# ___________________________________________________________________________________________________________________________________

# %% [markdown]
# ## ✨ DATA PRE-PROCESSING

# %% [markdown]
# ## 🍁 UNDERSTANDING OVERVIEW OF DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %% [markdown]
# ## 🍁 TOTAL NUMBER OF COLUMNS AND ROWS

# %%
df.shape
# Out:
# (128975, 24)

# %% [markdown]
# ## 🍁 ANALYSING DATA TYPES

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# dtype: object

# %% [markdown]
# # 🧹 DATA CLEANING

# %% [markdown]
# ## 🍁 FINDING OUR NULL VALUES IN DATA SET

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### ❄️ REPLACING NULL VALUES OF COURIER STATUS COLUMN

# %%
df['Courier Status'].fillna('Cancelled', inplace=True)

# %% [markdown]
# ### ❄️ REPLACING NULL VALUES OF CURRENCY WITH INR

# %%
df.fillna({'currency':'INR'}, inplace=True)

# %% [markdown]
# ### ❄️ REPLACING NULL VALUES OF AMOUNT COLUMN WITH MEAN VALUE

# %%
df['Amount'].mean().round(2)
# Out:
# 648.56

# %%
df.fillna({'Amount':648.56}, inplace =True)

# %% [markdown]
# ### ❄️ REPLACING NULL VALUES OF SHIP_CITY WITH MODE VALUE

# %%
df['ship-city'].mode()
# Out:
# 0    BENGALURU
# Name: ship-city, dtype: object

# %%
df.fillna({'ship-city': 'Bengaluru'}, inplace=True)

# %% [markdown]
# ### ❄️ REPLACING NULL VALUES OF SHIP-STATE WITH MODE VALUE

# %%
df['ship-state'].mode()
# Out:
# 0    MAHARASHTRA
# Name: ship-state, dtype: object

# %%
df.fillna({'ship-state':'Maharashtra'}, inplace=True)

# %% [markdown]
# ### ❄️ FILLING VALUES IN SHIP POSTAL CODE COLUMN

# %%
df.fillna({'ship-postal-code': 000000}, inplace=True)

# %% [markdown]
# ### ❄️ FILLING NULL VALUES OF SHIP COUNTRY WITH MODE VALUE

# %%
df['ship-country'].mode()
# Out:
# 0    IN
# Name: ship-country, dtype: object

# %%
df.fillna({'ship-country':'IN'}, inplace=True)

# %% [markdown]
# ### ❄️ FILLING NULL VALUES OF PROMOTION IDS WITH 'PROMO-NULL'

# %%
df.fillna({'promotion-ids':'PROMO-NULL'}, inplace=True)

# %% [markdown]
# ______________________________________________________________________________________________________________________________________

# %% [markdown]
# ### ❄️ FILLING NULL VALUES OF FULLFILLED-BY COLUMN WITH EASY SHIP

# %%
df['fulfilled-by'].mode()
# Out:
# 0    Easy Ship
# Name: fulfilled-by, dtype: object

# %%
df.fillna({'fulfilled-by':'Easy Ship'}, inplace=True)

# %% [markdown]
# ### 🌟 REMOVE UNNAMED COLUMN

# %%
df.drop(columns = 'Unnamed: 22', inplace=True)

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ## 🍒 RE-ASSURING FOR NULL VALUES

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %% [markdown]
# ____________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 🍁 FORMATTING COLUMN ATTRIBUTES

# %%
df['ship-city'] = df['ship-city'].str.strip().str.title()
df['ship-city']
# Out:
# 0              Mumbai
# 1           Bengaluru
# 2         Navi Mumbai
# 3          Puducherry
# 4             Chennai
#              ...
# 128970      Hyderabad
# 128971       Gurugram
# 128972      Hyderabad
# 128973          Halol
# 128974         Raipur
# Name: ship-city, Length: 128975, dtype: object

# %%
df['ship-state'] = df['ship-state'].str.strip().str.title()
df['ship-state']
# Out:
# 0          Maharashtra
# 1            Karnataka
# 2          Maharashtra
# 3           Puducherry
# 4           Tamil Nadu
#               ...
# 128970       Telangana
# 128971         Haryana
# 128972       Telangana
# 128973         Gujarat
# 128974    Chhattisgarh
# Name: ship-state, Length: 128975, dtype: object

# %%
df['Category'] = df['Category'].str.strip().str.title()
df['Category']
# Out:
# 0                   Set
# 1                 Kurta
# 2                 Kurta
# 3         Western Dress
# 4                   Top
#               ...
# 128970            Kurta
# 128971              Set
# 128972    Western Dress
# 128973              Set
# 128974              Set
# Name: Category, Length: 128975, dtype: object

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 🍁 CHECKING FOR DUPLICATE VALUES

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 🍁 STATISTICAL SUMMARY

# %% [markdown]
# ### 🍒 STATISTICAL SUMMARY OF NUMERICAL DATA

# %%
df.describe().T
# Out:
#                      count           mean            std  min       25%  \
# index             128975.0   64487.000000   37232.019822  0.0   32243.5
# Qty               128975.0       0.904431       0.313354  0.0       1.0
# Amount            128975.0     648.561376     272.581240  0.0     459.0
# ship-postal-code  128975.0  463847.524466  191596.021199  0.0  382421.0
#
#                        50%       75%       max
# index              64487.0   96730.5  128974.0
# Qty                    1.0       1.0      15.0
# Amount               635.0     771.0    5584.0
# ship-postal-code  500033.0  600024.0  989898.0

# %% [markdown]
# ### 🍒 STATISTICAL SUMMARY OF NON - NUMERICAL DATA

# %%
df.describe(include=object).T
# Out:
#                      count  unique                  top    freq
# Order ID            128975  120378  171-5057375-2831560      12
# Date                128975      91             05-03-22    2085
# Status              128975      13              Shipped   77804
# Fulfilment          128975       2               Amazon   89698
# Sales Channel       128975       2            Amazon.in  128851
# ship-service-level  128975       2            Expedited   88615
# Style               128975    1377              JNE3797    4224
# SKU                 128975    7195         JNE3797-KR-L     773
# Category            128975       9                  Set   50284
# Size                128975      11                    M   22711
# ASIN                128975    7190           B09SDXFFQ1     773
# Courier Status      128975       3              Shipped  109487
# currency            128975       1                  INR  128975
# ship-city           128975    7297            Bengaluru   11931
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 📊 EXPLORATORY DATA ANALYSIS AND VIZUALIZATION

# %% [markdown]
# ### 🔴 ANALYSING PERCENTAGE OF CATEGORY

# %%
vc = df['Category'].value_counts()
vc
# Out:
# Category
# Set              50284
# Kurta            49877
# Western Dress    15500
# Top              10622
# Ethnic Dress      1159
# Blouse             926
# Bottom             440
# Saree              164
# Dupatta              3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.pie( vc, labels=vc.index, autopct='%1.0f%%')
plt.axis('equal')
plt.title('PERCENTAGE OF CATEGORICAL DATA', size=20)
plt.show()

# %% [markdown]
# ## ✒️ INFERENCE :
#
# Top Five Product Categories by Sales.
#
#    ♦️ Dominant Category:
#
#          Kurtha is the top-selling category, with sales significantly higher than all other categories shown.
#
#    ♦️  Second-Highest Category:
#
#           'Set' is the second most popular category, with sales notably lower than 'kurta' but higher than the remaining three.
#
# Following Categories:
#
# The categories 'Western Dress', 'Top', and 'Dupatta' follow in descending order of sales, with their sales being much lower than those of 'kurta' and 'Set'.

# %%
cc = df['currency'].value_counts()
cc
# Out:
# currency
# INR    128975
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.pie(cc, labels=cc.index, autopct='%1.0f%%')
plt.axis('equal')
plt.title('PERCENTAGE OF CURRENCY USED', size=20)
plt.show()

# %% [markdown]
# ## ✒️ INFERENCE :
#
#         ♦️ Trading is done in INR.

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 STATUS COUNT

# %%
sc = df['Status'].value_counts().reset_index()
sc
# Out:
#                            Status  count
# 0                         Shipped  77804
# 1    Shipped - Delivered to Buyer  28769
# 2                       Cancelled  18332
# 3    Shipped - Returned to Seller   1953
# 4             Shipped - Picked Up    973
# 5                         Pending    658
# 6   Pending - Waiting for Pick Up    281
# 7   Shipped - Returning to Seller    145
# 8      Shipped - Out for Delivery     35
# 9     Shipped - Rejected by Buyer     11
# 10                       Shipping      8
# 11      Shipped - Lost in Transit      5
# 12              Shipped - Damaged      1

# %%
sc.columns = ['Status', 'Count']

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=sc, x='Status', y='Count', color='blue')
plt.title('Status Counts', size=20)
plt.xlabel('Status', size=20)
plt.ylabel('Count', size=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### ✒️ Inference :
#
#       ♦️ 77804 items are Shipped.
#
#       ♦️ 28769 items are Shipped - Delivered to Buyer.
#
#       ♦️ 18332 items are Cancelled.

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 CITIES WITH MAXIMUM REVENUE

# %%
df.groupby('ship-city')['Amount'].mean()
# Out:
# ship-city
# (Chikmagalur disterict).     (N.R pur thaluku)     389.0
# (Via Cuncolim)Quepem,South Goa                    1163.0
# ,HYDERABAD                                         563.0
# ,raibarely road faizabad (Ayodhya)                1122.0
# ..katra                                            641.0
#                                                    ...
# yavatmal                                           735.0
# yazali                                             487.0
# yellapur                                           824.0
# zirakpur                                           852.0
# लखनऊ                                              1001.5
# Name: Amount, Length: 8955, dtype: float64

# %%
top_10_ship_city = df.nlargest(10, 'Amount')

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=top_10_ship_city, x='ship-city', y='Amount', color='mediumslateblue')
plt.title('TOP 10 CITIES WITH MAXIMUM REVENUE' ,size=20)
plt.show()

# %% [markdown]
# ## ✒️ INFERENCE :
#
#              ♦️ Gontur with INR 5900 ranks the first , followed by Jalandhar 5600 INR.
#
#              ♦️ Kolkata and Chenni brings the lesser revenue of 2500 INR.

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 AVERAGE REVENUE OVER TIME

# %%
overall_mean = df['Amount'].mean()
overall_mean.round(2)
# Out:
# 648.56

# %%
df.groupby('Date')['Amount'].mean()
# Out:
# Date
# 03-31-22    627.678086
# 04-01-22    635.446843
# 04-02-22    627.130172
# 04-03-22    635.529761
# 04-04-22    641.964461
#                ...
# 06-25-22    678.666577
# 06-26-22    669.212820
# 06-27-22    676.895422
# 06-28-22    680.851437
# 06-29-22    654.261940
# Name: Amount, Length: 91, dtype: float64

# %%
plt.figure(figsize=(20,8))
df.groupby('Date')['Amount'].mean().plot()
plt.title('AVERAGE REVENUE OVER TIME', size=20)
plt.show()

# %% [markdown]
# ### ✒️ Inference :
#
#          ♦️ The average billing amount is 648.56.
#
#          ♦️ Based on the graph, the average daily revenue fluctuates, showing no consistent upward or downward trend across the observed period.

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 TOP 10 STATES WITH HIGHEST REVENUE

# %%
la = df.nlargest(10, 'Amount')

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=la, x = 'ship-state', y='Amount', color='violet', errorbar=None)
plt.title('TOP 10 STATES WITH HIGHEST REVENUE', size=20)
plt.show()

# %% [markdown]
# ### ✒️ Inference :
#
# ### 🔺 Highest Revenue States :
#
#                     Andra Pradesh is the state with highest revenue, 5900 INR.
#
#                     Followed by Punjab5600 INR.
#
# ### 🔺 lowest Revenue :
#
#                     West Bengal and Tamil Nadu is lowest amoung top 10 states , which contributes about 2500 INR.

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 AMOUNT GENERATED BY FULLFILLMENT

# %%
fc = df['Fulfilment'].value_counts().reset_index()
fc
# Out:
#   Fulfilment  count
# 0     Amazon  89698
# 1   Merchant  39277

# %%
plt.figure(figsize=(20,8))
sns.violinplot(data=df, x='Fulfilment', y='Amount', color='blue' )
plt.title('AMOUNT GENERATED BY FULLFILLMENT', size=20)
plt.show()

# %% [markdown]
# ### ✒️ Inference :
#
#          ♦️ Revenue generated by Merchant and Amazon is between INR 0 - 1800.
#
#          ♦️ Maximum amount generated by Merchant is arround 800 INR.
#
#          ♦️ Maximum amount generated by Amazon is arround INR 500.
#
#          ♦️ Maximum volume of sales is by Amazon followed Merchant.

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 AMOUNT GENERATED BY SHIP SERVICE LEVEL

# %%
sc = df['ship-service-level'].value_counts().reset_index()
sc
# Out:
#   ship-service-level  count
# 0          Expedited  88615
# 1           Standard  40360

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df, x='ship-service-level', y='Amount', color='green')
plt.title('AMOUNT GENERATED BY SHIP SERVICE LEVEL', size=20)
plt.show()

# %% [markdown]
# ### ✒️ Inference :
#
#           ♦️ Average sales of both are 650 INR.
#
#           ♦️ Range of sales of Standard ship sevice is between 500 INR to 850 INR.
#
#           ♦️ Range of sales of Expedited ship service is between 450 INR to 900 INR.

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 📩 CONCLUSION

# %% [markdown]
# #### The sales and revenue analysis reveals several key trends across shipping services, sellers, regions, and product categories:

# %% [markdown]
# ### 🔴 Shipping Services:
#        ♦️ Both Standard and Expedited shipping services maintain an average sales value of ₹650.
#
#        ♦️ However, Expedited shipping shows a wider range (₹450–₹900), indicating more variability in transaction amounts compared to Standard shipping (₹500–₹850).
#
# ### 🔴 Seller Performance:
#
#       ♦️ While Merchant sellers generate higher revenue per transaction (up to ₹800), Amazon leads in overall sales volume, suggesting a strategy focused on quantity over high-value transactions.
#
#       ♦️ Amazon’s maximum transaction value is around ₹500.

# %% [markdown]
# _______________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 Geographic Insights:

# %% [markdown]
# ### 🔺 Top Revenue States:
#
#            ♦️ Andhra Pradesh tops the chart with ₹5900 in revenue, closely followed by Punjab at ₹5600.
#
# ### 🔺 Lowest Revenue States:
#
#            ♦️ West Bengal and Tamil Nadu contribute the least among the top 10, each generating around ₹2500.
#
# ### 🔺 Top Cities:
#
#             ♦️ Gontur and Jalandhar are the highest revenue-generating cities, while Kolkata and Chennai trail behind.

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 Order Fulfillment

# %% [markdown]
#              🔺 Out of 77,804 items shipped, 28,769 were successfully delivered.
#
#              🔺 A significant portion, 18,332, were cancelled, highlighting potential issues in logistics or buyer behavior.

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴  Currency & Billing:

# %% [markdown]
#             🔺 All trading is conducted in INR, with an average billing amount of ₹648.56.
#
#             🔺 Daily revenue shows fluctuations without a clear upward or downward trend, indicating a dynamic market.

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 Product Category Performance:

# %% [markdown]
#                🔺 Kurtha dominates as the top-selling category.
#
#                🔺 Set ranks second, followed by Western Dress, Top, and Dupatta, each showing progressively lower sales.

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# ________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔮 Future Sales & Revenue Prediction
#
# Based on the existing patterns in shipping, seller performance, regional revenue, and product category dominance, here’s what the future may hold:
#
#
# ### 📦 Shipping Services
# - Expedited Shipping is likely to gain more traction due to its wider pricing flexibility and appeal to time-sensitive buyers. Expect a gradual increase in its share of total shipments.
#
# - Standard Shipping may remain stable but could lose ground if delivery speed becomes a more decisive factor for consumers.
#
#
# #### 🛍️ Seller Dynamics
# - Amazon, with its higher volume strategy, is poised to continue dominating in terms of units sold. However, Merchants may focus on premium offerings to boost per-transaction revenue.
#
# - A hybrid model—balancing volume and value—could emerge as the most profitable strategy.
#
#
# ### 🌍 Regional Growth
#
#
# - Andhra Pradesh and Punjab are likely to remain top contributors, but emerging urban centers in other states may begin to close the gap as e-commerce penetration deepens.
#
# - West Bengal and Tamil Nadu, currently lagging, may see growth if logistical challenges are addressed and local demand is stimulated through targeted marketing.

# %% [markdown]
# ________________________________________________________________________________________________________________________

# %% [markdown]
# ### 📈 Revenue Trends

# %% [markdown]
#         ♦️ With an average billing amount near ₹650 and fluctuating daily revenue, the market shows signs of volatility but also resilience.
#
#         ♦️ Expect seasonal spikes during festivals and sales events, with potential for a 10–15% increase in average daily revenue during peak periods.

# %% [markdown]
# _______________________________________________________________________________________________________________________

# %% [markdown]
# ### 👗 Product Category Forecast

# %% [markdown]
#         ♦️ Kurtha will likely retain its top spot due to cultural relevance and consistent demand.
#
#         ♦️ Set and Western Dress categories may grow if fashion trends shift or if bundled offerings become more attractive.
#
#         ♦️ Top and Dupatta may benefit from cross-selling strategies and influencer-driven campaigns.
